# %% [markdown]
# # Рабочая тетрадь №
# ## Тема: Марксовкие процессы и Системы массового обслуживания
#
# Термин ***система*** будет неоднократно употребляться в дальнейшем при изложении теории марковских процессов. Поэтому вначале сделаем небольшое отступление и дадим определение этого понятия.
#
# ***Системой*** называется целенаправленное множество взаимосвязанных элементов любой природы.
#
# Более строгое математически определение системы такое:
#
# Пусть A = {a_i} – множество некоторых объектов, обладающих определенными свойствами (элементы системы); R = {r_i} – связи между указанными объектами; Z – цель функционирования системы. Тогда систему можно определить, как совокупность элементов со связями и целью функционирования системы, т.е. S = {A, R, Z}
#
# Различают два вида систем:
# 1. Детерминированные;
# 2. Стахостатические.
#
# ***Детерминированными системами*** называются такие системы, состояние которых однозначно определяется начальными значениями и может быть однозначно предсказано для любого момента времени. Например, движение планет в солнечной системе - они всегда движутся по заранее известным законам физики, дверной замок - после вращения ключа мы всегда знаем в какую сторону будет двигаться ригель. Проще говоря, поведение нашей системы в любой момент времени **предсказуемо**.
#
# ***Стохастические системы*** – это такие системы, эволюция которых во времени не может быть описана однозначно. То есть будущее поведение системы и прогноз ее поведения носят случайный характер. Например, прогноз погоды - мы не можем со 100% уверенностью утверждать, что через несколько дней будет солнечная безветренная погода, так как всегда есть угроза дождя или произойдет изменение интенсивности солнечного излучения. Нашего знания о текущем состоянии системы и особенностей связей между ее составными элементами недостаточно для однозначного предсказания будущего системы.
#
# Поведение некоторых стохастических систем,  мы можем моделировать с помощью марковских случайных процессов, к обсуждению которых мы и переходим.

# %% [markdown]
# # Марковские процессы
#
# Случайный процесс называется марковским, если ***для любого момента времени вероятностные характеристики процесса в будущем
# зависят только от его состояния в данный момент времени и не зависят от того, когда и как система пришла в это состояние.*** («Будущее
# зависит от прошлого только через настоящее»).
#
# ## Классификация марковских процессов
# Все марковские процессы можно разделить на классы в зависимости от:
# 1. Множество состояний системы {S};
# 2. Множество моментов времени наблюдения {T}.
#
# Если множество {S} дискретное, то случайный процесс называется ***цепью Маркова***.
#
# Когда
# 1. {T} − дискретное множество, то процесс называется ***цепью Маркова с дискретным временем*** (или ***дискретной цепью Маркова***);
# 2. {T} − непрерывное множество, то процесс называется ***цепью Маркова с непрерывным временем*** (или ***непрерывной цепью Маркова***).
#
# Если {S} непрерывное и {T} непрерывное, то процесс называется ***непрерывным марковским процессом***.
#
# Далее будут рассматриваться **цепи Маркова с дискретным и непрерывным временем**.

# %% [markdown]
# # Цепи Маркова с дискретным временем
#
# Рассмотрим случайный процесс, при котором система может находиться в состояниях S_1, S_2, ..., S_k, а изменения состояний могут происходить в определённые моменты времени t_1, t_2, ..., t_n.
#
# Пусть в момент времени t(m), система находилась в состоянии S_i, a в момент времени t(m+1) в состоянии S_j.
#
# Переходы из одного состояния в другое происходят с вероятностью p_i_j , через равные промежутки времени |t(m+1) - t(m)| = 1, которые мы будем называть ***шагом***.
#
# Процесс будет марковским, если эта вероятность на каждом шаге зависит только от состояния, в которое система попала на предыдущем шаге, и не зависит от предыдущих шагов. Иначе говоря, для марковского процесса переходная вероятность не должна зависеть от m.
#
# Переходный вероятности образуют ***матрицу переходных вероятностей***.
#
# Цепи маркова с дискретным временем бывают ***однородные*** и ***неоднородные***.
#
# Если вероятности переходов не зависят от момента времени t , то есть p_i_j(t) = p_i_j , то цепь Маркова называется ***однородной*** с матрицей вероятностей переходов за один шаг:
#
# ![](pictures\possibilities_matrix.png)
#
# Для ***однородной цепи Маркова*** стохастическая матрица P имеет постоянный вид, для любого шага, т.е. P(1) = P(2) = P(3) = ... P(n), где (1), (2), ... (n) – номера шагов.
#
# Если исследуемая ***цепь Маркова неоднородная***, то матрицы вероятностей переходов для
# каждого шага P(1), P(2), P(3), ..., P(n) будут разными.
#
# Для того чтобы определить цепь Маркова с дискретным временем необходимо обязательно задать ***начальное распределение***.
# Т.е. начальное распределение – это распределение вероятностей состояний системы в момент времени t = 0 . Этим моментом может быть например тот, начиная с которого мы стали наблюдать за нашей системой.
#
# **Задание 1:**
# - Придумать цепь Маркова с n количеством состояний и начальным распределением
# - Изобразить матрицу переходных вероятностей в виде графа
#
# **Решение:**
#
# Рассмотрим цепь Маркова, обладающую тремя
# состояниями и предназначенную для моделирования погоды.
# Предполагается, что раз в день (например, в полдень) состояние погоды
# описывается одной и только одной из следующих характеристик: S_1 –
# осадки, S_2 – облачно, S_3 – ясно. Матрица переходных вероятностей P имеет
# вид:
#
# |0.4| 0.3| 0.3|
#
# |0.2| 0.6| 0.2|
#
# |0.1| 0.1| 0.8|
#
# (Например: вероятность того, что после облачного дня снова будет
# облачно, равна 0.6; вероятность того, что после ясного дня будет дождь, равна 0.1)
#
# Известно,
# что сегодня – ясный день.

# %%
import numpy as np
import matplotlib.pyplot as plt
from netgraph import Graph

# Запишем начальное распределение
initial_distribution = np.array([0, 0, 1])

# Запишем матрицу переходных вероятностей
P = np.array([[0.4, 0.3, 0.3] , [0.2, 0.6, 0.2], [0.1, 0.1, 0.8]])

# Создадим граф на основе переходных вероятностей
sources, targets = np.where(P)
weights = P[sources, targets]
edges = list(zip(sources, targets))
edge_labels = dict(zip(edges, weights))

# Нарисуем граф
fig, ax = plt.subplots(figsize=(15, 7))
Graph(edges, edge_labels=edge_labels, edge_label_position=0.66, node_labels=True, arrows=True, ax=ax, width=1)
plt.show()

# %%
# Задание для самостоятельного решения
# Придумать цепь Маркова с n количеством состояний и начальным распределением
# Изобразить матрицу переходных вероятностей в виде графа

# %% [markdown]
# # Распределение вероятностей состояний системы за k шагов
#
# Для **однородных цепей Маркова** нужно сперва возвести матрицу переходных вероятностей возвести в степень k.
#
# Затем начальное распределение нужно перемножить на полученную матрицу.
#
# ![](pictures\odnor_ver.png)
#
# Для **неоднородных цепей Маркова** мы перемножаем начальное распределение на матрицы переходных вероятностей до k матрицы
#
# ![](pictures\neodnor_ver.png)
#
# # Стационарное распределение вероятностей состояний системы
#
# Распределение вероятностей называется ***стационарным***, если оно не изменяется от шага к шагу.
#
# Для того, чтобы марковская цепь с конечным числом состояний имела единственное стационарное предельное распределение вероятностей, необходимо и достаточно, чтобы все существенные состояния были сообщающимися.
#
# Состояние называется сообщающимся, если из него можно перейти в другие состояния.
#
# ***Предельная стационарная вероятность несущественного состояния всегда оказывается равной нулю***: рано или поздно система выходит из этого состояния и уже в него не возвращается.
#
# ***Предельная стационарная вероятность единственного состояния поглощения (при отсутствии других классов существенных состояний) всегда оказывается равной единице***: рано или поздно система придёт в это состояние и уже из него не выйдет.
#
# **Задание 2:**
#
# Матрица парехода P имеет вид:
#
# | 0.4 | 0.6 |
#
# | 0.3 | 0.7 |
#
# Начальное распределение вероятностей: (0.1, 0.9)
#
# Найти:
# 1. матрицу перехода за 2 шага;
# 2. распределение вероятностей по состояниям после 2-го шага;
# 3. вероятность того, что после 1-го шага состоянием цепи будет S_1
# 4. стационарное распределение вероятностей по состояниям.

# %%
import numpy as np


# Запишем начальное распределение
initial_distribution = np.array([0.1, 0.9])

# Запишем матрицу переходных вероятностей
P = np.array([[0.4, 0.6] , [0.3, 0.7]])

# 1: Матрица перехода за 2 шага
P_2 = np.linalg.matrix_power(P, 2)
print(f'Матрица переходов за 2 шага: \n{P_2}')
# Как мы видим сумма по строкам осталась равна 1 (самопроверка)

# 2: Распределение вероятностей по состояниям после 2-го шага
distribution_2 = np.matmul(initial_distribution, P_2)
print(f'Распределение вероятностей по состояниям после 2-го шага: \n{distribution_2}')
# Как мы видим сумма осталась равна 1 (самопроверка)

# 3: Вероятность того, что после 1-го шага состоянием цепи будет S_1
# Для этого нам нужно перемножить начальное распределение на первый стобец матрицы преходных вероятностей
P1 = np.matmul(initial_distribution, P[:, :1])
print(f'Вероятность того, что после 1-го шага состоянием цепи будет S_1: \n{P1}')
# Out:
# Матрица переходов за 2 шага:
# [[0.34 0.66]
#  [0.33 0.67]]
# Распределение вероятностей по состояниям после 2-го шага:
# [0.331 0.669]
# Вероятность того, что после 1-го шага состоянием цепи будет S_1:
# [0.31]

# %%
# 4: Стационарное распределение вероятностей по состояниям
############
# СПОСОБ 1 #
############
# Будем возводить нашу исходную матрицу переходных вероятностей
# до тех пор пока распределение станет стационарным
for i in range(0, 10, 2):
    print('-' * 100)

    matrix = np.linalg.matrix_power(P, i)
    distribution = np.matmul(initial_distribution, matrix)
    print(f'Шаг = {i}\n', distribution)
# Out:
# ----------------------------------------------------------------------------------------------------
# Шаг = 0
#  [0.1 0.9]
# ----------------------------------------------------------------------------------------------------
# Шаг = 2
#  [0.331 0.669]
# ----------------------------------------------------------------------------------------------------
# Шаг = 4
#  [0.33331 0.66669]
# ----------------------------------------------------------------------------------------------------
# Шаг = 6
#  [0.3333331 0.6666669]
# ----------------------------------------------------------------------------------------------------
# Шаг = 8
#  [0.33333333 0.66666667]

# %%
# Уже на 2 шаге мы получили стационарное распределение по вероятностям
# Выведем их в виде дробей (Fraction)
from fractions import Fraction

print([Fraction(number).limit_denominator(1000) for number in distribution])
# Out:
# [Fraction(1, 3), Fraction(2, 3)]

# %% [markdown]
# Смысл полученного результата таков: в установившемся режиме система будет одну треть времени проводить в состоянии S_1 и две трети — в состоянии S_2.
#
# **2-й способ нахождения стационарного распределения вероятностей:**
#
# ![](pictures\4_task.png)
#
# **Задание для самостоятельного решения:**
#
# Имеется предприятие, выпускающее некоторый товар А.
# Вероятность того, что этот товар будет пользоваться достаточным спросом, равна 0,5. Если в течение недели товар пользуется спросом, то выпуск
# его продолжается. В противном случае на следующей неделе предприятие
# выпускает другой товар В, имеющий вероятность достаточного спроса 0,6.
# Если спрос на товар В становится недостаточным, то с новой недели опять
# выпускается товар А, и т.д. С какой вероятностью предприятие будет выпускать товар A через неделю? Через две недели? Какую долю времени в
# целом предприятие будет выпускать товар A, и какую — товар B?
#
#  \* Нарисовать граф переходных состояний

# %%
# Будем считать, что система S (данное предприятие) находится в
# состоянии S1, если выпускается товар А, и в состоянии S2 , если выпускается
# товар B. Если система находится в состоянии S1 , то с вероятностью 0,5 она
# останется в этом состоянии к концу недели и с вероятностью 0,5 может перейти в состояние S2.
# Если же система находится в состоянии S2, то выпускается товар В, и с вероятностью 0,4 система может вернуться в состояние
# S1, а с вероятностью 0,6 может остаться в состоянии S2. Таким образом,
# матрица вероятности переходов имеет вид

P = np.array([[0.5, 0.5], [0.4, 0.6]])

initial_distribution = np.array([1, 0])

# Определим распределение вероятностей состояний системы через 1 шаг (через неделю).
distribution_1 = np.matmul(initial_distribution, P)
print(f'C вероятностью = {P1[0]} предприятие будет выпускать товар А через неделю')

# Определим распределение вероятностей состояний системы через 2 шаг (через 2 недели).
distribution_2 = np.matmul(initial_distribution, np.linalg.matrix_power(P, 2))
print(f'C вероятностью = {distribution_2[0]} предприятие будет выпускать товар А через неделю')

# Определим стационарные вероятности
for i in range(0, 10, 2):
    print('-' * 100)

    matrix = np.linalg.matrix_power(P, i)
    distribution = np.matmul(initial_distribution, matrix)
    print(f'Шаг = {i}\n', distribution)

print(f'Стационарное распределение вероятностей: {[Fraction(number).limit_denominator(1000) for number in distribution]}')
# Out:
# C вероятностью = 0.31000000000000005 предприятие будет выпускать товар А через неделю
# C вероятностью = 0.45 предприятие будет выпускать товар А через неделю
# ----------------------------------------------------------------------------------------------------
# Шаг = 0
#  [1. 0.]
# ----------------------------------------------------------------------------------------------------
# Шаг = 2
#  [0.45 0.55]
# ----------------------------------------------------------------------------------------------------
# Шаг = 4
#  [0.4445 0.5555]
# ----------------------------------------------------------------------------------------------------
# Шаг = 6
#  [0.444445 0.555555]
# ----------------------------------------------------------------------------------------------------
# Шаг = 8
#  [0.44444445 0.55555555]
# Стационарное распределение вероятностей: [Fraction(4, 9), Fraction(5, 9)]

# %% [markdown]
# Предприятие примерно 44,4% времени будет выпускать товар А, остальное время — товар B.
#
# Нахождение стационарных вероятностей 2-м способом:
#
# ![](pictures\task_2_4.png)
#
# **Задание для самостоятельного решения:**
#
# ![](pictures\lab_5_task_3.png)

# %%
# задача А

matrix = np.array([[0.2, 0.6, 0.2],
                   [0.4, 0.6, 0],
                   [0, 0.5, 0.5]])



for i in range(1, 4):
    print(f'Шаг: {i}\nМатрица переходных вероятностей\n{matrix}')
    print('-' * 100)
    matrix = np.matmul(matrix, matrix)
# Out:
# Шаг: 1
# Матрица переходных вероятностей
# [[0.2 0.6 0.2]
#  [0.4 0.6 0. ]
#  [0.  0.5 0.5]]
# ----------------------------------------------------------------------------------------------------
# Шаг: 2
# Матрица переходных вероятностей
# [[0.28 0.58 0.14]
#  [0.32 0.6  0.08]
#  [0.2  0.55 0.25]]
# ----------------------------------------------------------------------------------------------------
# Шаг: 3
# Матрица переходных вероятностей
# [[0.292  0.5874 0.1206]
#  [0.2976 0.5896 0.1128]
#  [0.282  0.5835 0.1345]]
# ----------------------------------------------------------------------------------------------------

# %%
# задача Б

start = np.array([1, 0, 0])
P = np.array([[0.2, 0.6, 0.2],
                   [0.4, 0.6, 0],
                   [0, 0.5, 0.5]])

for step in range(1, 4):
    matrix = np.linalg.matrix_power(matrix, i)
    start = np.matmul(start, matrix)
    print(f'Шаг: {step}\nСостояние системы: {start}')
    print('-' * 100)
# Out:
# Шаг: 1
# Состояние системы: [0.29411765 0.58823529 0.11764706]
# ----------------------------------------------------------------------------------------------------
# Шаг: 2
# Состояние системы: [0.29411765 0.58823529 0.11764706]
# ----------------------------------------------------------------------------------------------------
# Шаг: 3
# Состояние системы: [0.29411765 0.58823529 0.11764706]
# ----------------------------------------------------------------------------------------------------

# %%
# Задача В
from fractions import Fraction

print(f'Стационарный вероятности: {[Fraction(number).limit_denominator(1000) for number in start]}')
# Out:
# Стационарный вероятности: [Fraction(5, 17), Fraction(10, 17), Fraction(2, 17)]

# %% [markdown]
# # Цепь Маркова с непрерывным временем
#
# Ранее мы рассмотрели дискретные цепи Маркова, когда система может находиться в одном из дискретных состояний S_1, S2, ..., S_n и в **фиксированные** моменты времени t_1, t_2, ..., t_n переходит из одного состояния в другое.
#
# Рассмотрим теперь марковский процесс конечным или счетным множеством состояний {S}, который изменяет свои состояния в случайные моменты времени. Такой процесс
# называется ***цепью Маркова с непрерывным временем***.
#
# ***В этом случае говорить о вероятности перехода системы из одного состояния в другое в любой определённый момент времени бессмысленно*** (она равна нулю, подобно вероятности любого значения непрерывной случайной величины). ***Можно говорить только о вероятности перехода за промежуток времени ∆t (подразумевается, что за малый промежуток изменение не может произойти более 1 раза).***
#
# Поэтому мы имеем дело с плотностью вероятности. А для цепи маркова с непрерывным временем плотоность вероятности перехода системы из состояния S_i в состояние S_j называется  ***интенсивностью перехода***.
#
# ***Поскольку интенсивность можно рассматривать как производную от вероятности перехода, её знак показывает направление изменения вероятности этого перехода с ростом времени.*** Вероятность перехода в **иное** состояние, естественно, растёт. Вероятность же остаться **в том же состоянии со временем падает.**
#
# ![](pictures\intensity_matrix.png)
#
# Матрица интенсивностей аналог матрицы переходных вероятностей.
#
# ![](pictures\internsity_task_1.png)
#
# **Стационарное распределение вероятностей** находиться с помощью  ***Системы уравнений Колмогорова***
#
# **Задание 3:**
#
# Матрица интесивностей имеет вид:
#
# | 0 | 0 | 1 | 3 |
#
# | 4 | 0 | 3 | 0 |
#
# | 0 | 3 | 0 | 4 |
#
# | 0 | 1 | 1 | 0 |
#
# - Построить граф переходов между состояниями, ребра которого помечены соответствующими интенсивностями переходов.
# - Найти стационарное распределение вероятностей

# %%
intensity_matrix = np.array([[0, 0, 1, 0],
                             [4, 0, 3, 0],
                             [0, 3, 0, 4],
                             [0, 1, 1, 0]])

# Создадим граф на основе переходных вероятностей
sources, targets = np.where(intensity_matrix)
weights = intensity_matrix[sources, targets]
edges = list(zip(sources, targets))
edge_labels = dict(zip(edges, weights))

# Нарисуем граф
fig, ax = plt.subplots(figsize=(15, 7))
Graph(edges, edge_labels=edge_labels, edge_label_position=0.66, node_labels=True, arrows=True, ax=ax, width=1)
plt.show()

# %%
import numpy as np
from fractions import Fraction


def get_equation(matrix: np.ndarray, indx: int) -> np.array:
    """
    Получение i-го вектора для уравнений Колмогорова

    Args:
        matrix (np.ndarray): Матрица Марквоского процесса
        indx (int): Индекс вектора в уравнениях Колмагорова

    Returns:
        np.array: Полученный вектор
    """
    vector = [0 for _ in range(len(matrix) + 1)]

    input_intesity = matrix[:, indx]
    vector[0: len(matrix)] = input_intesity

    output_intensity = sum(matrix[indx, :]) * -1
    vector[indx] = output_intensity

    return vector

intensity_matrix = np.array([[0, 0, 1, 0],
                   [4, 0, 3, 0],
                   [0, 3, 0, 4],
                   [0, 1, 1, 0]])
system_of_equations = np.array([[1 for _ in range(len(intensity_matrix) + 1)]])

for indx in range(len(intensity_matrix)):
    vector = get_equation(intensity_matrix, indx)
    system_of_equations = np.vstack([system_of_equations, vector])

print(f'Система уравнений Колмогорова \n {system_of_equations}')

# Решим систему
system_of_equations = system_of_equations[:-1, :]
a = system_of_equations[:, :-1]
b = system_of_equations[:, -1]
result = np.linalg.solve(a, b)
result = [Fraction(number).limit_denominator(1000) for number in result]
print(f'Стационарные вероятности: {result}')
# Out:
# Система уравнений Колмогорова
#  [[ 1  1  1  1  1]
#  [-1  4  0  0  0]
#  [ 0 -7  3  1  0]
#  [ 1  3 -7  1  0]
#  [ 0  0  4 -2  0]]
# Стационарные вероятности: [Fraction(10, 23), Fraction(5, 46), Fraction(7, 46), Fraction(7, 23)]

# %% [markdown]
# **Задание для самостоятельного решения:**
#
# ![](pictures\lab_5_task_2.png)
#
# \* Построить граф переходных вероятностей

# %%
import numpy as np
from fractions import Fraction


def get_equation(matrix: np.ndarray, indx: int) -> np.array:
    """
    Получение i-го вектора для уравнений Колмогорова

    Args:
        matrix (np.ndarray): Матрица Марквоского процесса
        indx (int): Индекс вектора в уравнениях Колмагорова

    Returns:
        np.array: Полученный вектор
    """
    vector = [0 for _ in range(len(matrix) + 1)]

    input_intensity = matrix[:, indx]
    vector[0: len(matrix)] = input_intensity

    output_intensity = sum(matrix[indx, :]) * -1
    vector[indx] = output_intensity

    return vector

intensity_matrix = np.array([[0, 1, 0, 0],
                   [1, 0, 0, 1],
                   [0, 2, 0, 1],
                   [0, 0, 3, 0]])
system_of_equations = np.array([[1 for _ in range(len(intensity_matrix) + 1)]])

for indx in range(len(intensity_matrix)):
    vector = get_equation(intensity_matrix, indx)
    system_of_equations = np.vstack([system_of_equations, vector])

# Решим систему
system_of_equations = system_of_equations[:-1, :]
a = system_of_equations[:, :-1]
b = system_of_equations[:, -1]
result = np.linalg.solve(a, b)
result = [Fraction(number).limit_denominator(1000) for number in result]
print(f'Стационарные вероятности: {result}')

# Найдем матожидание
E = sum([indx * value  for indx, value in enumerate(result)])
print(f'Мат. ожидание: {E}')
# Out:
# Стационарные вероятности: [Fraction(1, 3), Fraction(1, 3), Fraction(1, 6), Fraction(1, 6)]
# Мат. ожидание: 7/6

# %%
# Создадим граф на основе переходных вероятностей
sources, targets = np.where(intensity_matrix)
weights = intensity_matrix[sources, targets]
edges = list(zip(sources, targets))
edge_labels = dict(zip(edges, weights))

# Нарисуем граф
fig, ax = plt.subplots(figsize=(15, 7))
Graph(edges, edge_labels=edge_labels, edge_label_position=0.66, node_labels=True, arrows=True, ax=ax, width=1)
plt.show()

# %% [markdown]
# # Системы массового обслуживания
#
# ***Системами массового обслуживания*** называются системы, удовлетворяющие массовый спрос в форме так называемых заявок, поступающих
# в случайные моменты времени и образующих ***входящий поток заявок***. Обслуженные заявки образуют ***выходящий поток обслуженных заявок***. Примеры СМО: телефонные станции, ремонтные мастерские, билетные кассы, магазины и т.д.
#
# Устройство, обслуживающее заявку, называется ***каналом обслуживания***. СМО может быть ***одноканальной*** или ***многоканальной***. Примеры каналов: линии связи, лифты, продавцы и т.д.
#
# Если заявка, поступившая в момент занятости СМО, покидает её без обслуживания, то СМО называется СМО ***с отказами***. Если же заявка ожидает освобождения канала обслуживания, то это СМО ***с очередью*** (с ожиданием).
#
# Процесс работы СМО представляет собой ***случайный процесс с дискретными состояниями и непрерывным временем (цепь Маркова).***
#
#
# # Одноканальная СМО с отказами
# Показатели эффективности:
# - A - абсолютная пропускная способность СМО, т.е. среднее число заявок, обслуживаемых в единицу времени;
# - Q - относительная пропускная способность СМО, т.е. средняя доля пришедших заявок, обслуживаемых системой;
# - P_отк - вероятность отказа, т. е. вероятность того, что заявка покинет СМО не обслуженной.
#
# Система состоит из одного канала обслуживания. Очередь не допускается. Заявка, пришедшая в тот момент, когда канал занят обслуживанием, уходит из системы необслуженной.
# Поток заявок и поток обслуживаний — простейшие.
# Система может находиться только в двух состояниях: S_0 — канал свободен и S_1 — канал занят. Р
# Обозначим, что λ — интенсивность потока заявок, т.е. среднее число поступающих заявок в единицу времени; μ — интенсивность потока обслуживаний.
#
# ![](pictures\smo_one_channel.png)
#
# ![](pictures\smo_one_channel_theory.png)
#
# **Задание 4:**
#
# Секретарю поступает в среднем 1,2 телефонных вызовов в минуту. Средняя продолжительность разговора 𝑡обс составляет 30 секунд.
# Найти основные характеристики СМО и оценить эффективность ее работы.
#
# **Решение:**
#
# Исходя из начального условия: λ = 1.2 (мин^(-1)) и μ = 2 (мин^(-1))
#
# Тогда
#
# p_обс = p0 = Q = 2 / (2 + 1.2) = 0.625
#
# p_отк = p1 = 1.2 / (2 + 1.2) = 0.375
#
# Обслуживается только 62,5 % звонков, 37,5 % звонков получают отказ (теряются)
#
# Найдем абсолютную пропускную способность СМО: A = λ*Q = 1.2 * 0.625 (1/мин) = 0.75 (мин^(-1)). Т.е. в среднем обслуживается 0,75 звонка в минуту.
#
# **Задание для самостоятельного решения:**
#
# ![](pictures\smo_one_channel_tasks.png)
#
# **Решение:**
#
# ![](pictures\smo_one_channel_1.png)
#
# ![](pictures\smo_one_channel_2.png)

# %% [markdown]
# # Многоканальная СМО с отказами
#
# **Задача Эрланга.** Имеется n каналов, на которые поступает поток заявок с интенсивностью λ. Поток обслуживаний имеет интенсивность μ.
#
# Будем рассматривать систему, работающую без очереди, т.е. с отказами в обслуживании заявкам, пришедшим в тот момент,
# когда все каналы системы заняты обслуживанием ранее пришедших заявок.
#
# Состояния системы будем нумеровать по числу заявок, находящихся на обслуживании в системе, т. е. S_k — состояние системы, когда в ней
# находится k заявок (занято k каналов).
#
# Граф системы выглядит следующим образом:
#
# ![](pictures\smo_more_channels.png)
#
# Поток заявок в систему не зависит от состояния каналов системы, поэтому при любом числе занятых каналов этот поток сохраняет свою интенсивность,
# следовательно, для любого состояния системы входящий в это состояние поток заявок (это поток событий, переводящих систему из предыдущего состояния в данное)
# имеет интенсивность λ. Интенсивность потока обслуживаний равна μ. Это значит, что каждый канал может обслуживать непрерывный поток заявок с интенсивностью μ.
# Событием такого потока является выход обслуженной заявки из системы, т. е. освобождение канала.
# Следовательно, μ можно рассматривать как интенсивность освобождения канала после очередного обслуживания заявки.
# Если в системе заняты два канала (т. е. ее состояние S_2 ), то может освободиться любой из них с интенсивностью μ, это значит,
# что суммарная интенсивность перехода в состояние S1 (занят один канал) равна 2μ. Точно так же, если система находится в состоянии Sk (заняты k каналов),
# то интенсивность входящего в такое состояние системы потока заявок равна λ, а интенсивность выходящего из этого состояния системы потока обслуживаний
# (т.е. интенсивность освобождения одного из k занятых каналов) равна kμ, т.к. любой из занятых k каналов может освободиться с интенсивностью μ.
# Таким образом, kμ — это интенсивность перехода системы из состояния Sk в состояние Sk−1 .
# При этом λ — это интенсивность перехода системы под влиянием потока заявок из состояния Sk−1 в Sk .
#
# Введем новый параметр: **p = λ / μ**
#
# Этот параметр называют приведенной интенсивностью потока заявок, или интенсивностью нагрузки каналов, или трафиком.
# Он выражает среднее число заявок, приходящих за среднее время обслуживания одной заявки.
#
# С учетом введенного параметра получим предельные вероятности состояний системы в следующем виде:
#
# ![](pictures\smo_more_channels_pokaz.png)

# %% [markdown]
# **Задание 5:**
#
# Определить минимально допустимое количество операторов call-центра, если известно, что в среднем, поступает 1,6 звонка в
# минуту, средняя продолжительность разговора составляет 88 секунд и число необслуженных клиентов может составить не более 10 %.

# %%
# Выпишем начальные параметры
λ = 1.6
μ = round(1 * 60 / 88, 2)

p = round(λ / μ, 2)

print(f'Интенсивность поступления звонков {λ = } (мин^(-1))')
print(f'Время обработки одного звонка {μ = } (мин^(-1))')
print(f'Коэффициент загруженности СМО {p = }')
# Out:
# Интенсивность поступления звонков: λ = 1.6 (мин^(-1))
# Время обработки одного звонка: μ = 0.68 (мин^(-1))
# Коэффициент загруженности СМО: p = 2.35

# %%
# Для того, чтобы количество необслуженных клиентов составляло не более 10%, необходимо чтобы параметр Q был больше 0.9 или p_отк меньше 0.1
# Для этого нам необходимо увеличивать количество каналов

from math import factorial

def calculate_p_0(p: float, n: int) -> float:
    """
    Расчет вероятности нахождения системы в состоянии S_0
    (все каналы свободны)

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов

    Returns:
        Рассчитанная вероятность
    """

    p_0 = 0
    for i in range(n + 1):
        p_0 += p ** i / factorial(i)

    p_0 = round(pow(p_0, -1), 4)
    return p_0

def calculate_p_n(p: float, n: int) -> float:
    """
    Расчет вероятности отказа обслуживания
    (все каналы заняты или система в состоянии S_n)

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов

    Returns:
        Рассчитанная вероятность
    """

    p_0 = calculate_p_0(p, n)

    p_n = p ** n * p_0 / factorial(n)
    p_n = round(p_n, 4)
    return p_n

def calculate_Q(p: float, n: int) -> float:
    """
    Расчет вероятности  обслуживания заявки

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов

    Returns:
        Рассчитанная вероятность
    """
    p_n = calculate_p_n(p, n)
    Q = round(1 - p_n, 4)
    return Q

def calculate_A(p: float, n: int, λ: float) -> float:
    """
    Расчет вероятности  обслуживания заявки

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов
        λ (float): Интенсивность поступления заявок

    Returns:
        Рассчитанная вероятность
    """
    Q = calculate_Q(p, n)
    A = round(Q * λ, 4)
    return A

# %%
import pandas as pd

df = pd.DataFrame(columns=['n', 'p_0', 'p_отк', 'Q', 'A'])

for  i in range(1, 6):
    df.loc[i] = (i, calculate_p_0(p, i), calculate_p_n(p, i), calculate_Q(p, i), calculate_A(p, i, λ))

df['n'] = df['n'].astype('int')
df
# Out:
#    n     p_0   p_отк       Q       A
# 1  1  0.2985  0.7015  0.2985  0.4776
# 2  2  0.1636  0.4517  0.5483  0.8773
# 3  3  0.1209  0.2615  0.7385  1.1816
# 4  4  0.1048  0.1332  0.8668  1.3869
# 5  5  0.0986  0.0589  0.9411  1.5058

# %% [markdown]
# Относительная пропускная способность 𝑄 составляет 0.941, что соответствует вероятности обслуживания, равной 94,1 %. Вероятность отказа в обслуживании в случае работы 5 операторов составляет 5,9 %, что соответствует начальным условиям задачи. Следовательно, можно записать следующий ответ: минимальное число операторов call-центра составит 5 человека.
#
# **Задание для самостоятельного решения:**
#
# ![](pictures\smo_more_channels_1.png)

# %%
# Выпишем начальные параметры
λ = 1.5
μ = 2

p = round(λ / μ, 2)

print(f'Интенсивность поступления автомобилей {λ = } (мин^(-1))')
print(f'Время осмотра автомобиля {μ = } (мин^(-1))')
print(f'Коэффициент загруженности СМО {p = }')
# Out:
# Интенсивность поступления автомобилей: λ = 1.5 (мин^(-1))
# Время осмотра автомобиля: μ = 2 (мин^(-1))
# Коэффициент загруженности СМО: p = 0.75

# %%
# Для того, чтобы количество необслуженных клиентов составляло не более 10%, необходимо чтобы параметр Q был больше 0.9 или p_отк меньше 0.1
# Для этого нам необходимо увеличивать количество каналов

from math import factorial

def calculate_p_0(p: float, n: int) -> float:
    """
    Расчет вероятности нахождения системы в состоянии S_0
    (все каналы свободны)

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов

    Returns:
        Рассчитанная вероятность
    """

    p_0 = 0
    for i in range(n + 1):
        p_0 += p ** i / factorial(i)

    p_0 = round(pow(p_0, -1), 4)
    return p_0

def calculate_p_n(p: float, n: int) -> float:
    """
    Расчет вероятности отказа обслуживания
    (все каналы заняты или система в состоянии S_n)

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов

    Returns:
        Рассчитанная вероятность
    """

    p_0 = calculate_p_0(p, n)

    p_n = p ** n * p_0 / factorial(n)
    p_n = round(p_n, 4)
    return p_n

def calculate_Q(p: float, n: int) -> float:
    """
    Расчет вероятности  обслуживания заявки

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов

    Returns:
        Рассчитанная вероятность
    """
    p_n = calculate_p_n(p, n)
    Q = round(1 - p_n, 4)
    return Q

def calculate_A(p: float, n: int, λ: float) -> float:
    """
    Расчет вероятности  обслуживания заявки

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов
        λ (float): Интенсивность поступления заявок

    Returns:
        Рассчитанная вероятность
    """
    Q = calculate_Q(p, n)
    A = round(Q * λ, 4)
    return A

# %%
import pandas as pd

df = pd.DataFrame(columns=['n', 'p_0', 'p_отк', 'Q', 'A'])

for  i in range(1, 5):
    df.loc[i] = (i, calculate_p_0(p, i), calculate_p_n(p, i), calculate_Q(p, i), calculate_A(p, i, λ))

df['n'] = df['n'].astype('int')
df
# Out:
#    n     p_0   p_отк       Q       A
# 1  1  0.5714  0.4285  0.5715  0.8573
# 2  2  0.4923  0.1385  0.8615  1.2923
# 3  3  0.4758  0.0335  0.9665  1.4498
# 4  4  0.4729  0.0062  0.9938  1.4907

# %% [markdown]
# # Одноканальная СМО с ограниченной очередью
#
# Рассмотрим систему с одним каналом обслуживания и очередью, допустимой, если она не превышает числа m > 0.
# Состояния системы будем нумеровать по числу заявок, находящихся в системе, т. е. S_k — состояние системы, когда
# в ней находится k заявок:
# - S_0 — система свободна: канал не занят, очереди нет;
# - S_1 — канал занят, обслуживается одна заявка, очереди нет;
# - S_2 — канал занят, обслуживается одна заявка, одна заявка стоит в очереди;
# - S_3 — канал занят, две заявки стоят в очереди;
# - ...
# - S_m+1 — канал занят, m заявок стоят в очереди, т.е. все допустимые места в очереди заняты, очередной заявке, поступившей в систему, будет
# отказано в обслуживании.
#
# Общее число состояний системы в рассматриваемом случае равно m + 2. Потоки заявок и обслуживания предполагаются простейшие, их интенсивности равны, соответственно, λ и μ.
#
# Размеченный граф системы выглядит следующим образом:
#
# ![](pictures\smo_one_queue.png)
#
# Поток заявок в систему при любом ее состоянии сохраняет свою интенсивность, которая равна λ, следовательно, для любого состояния системы переход из состояния S_k
# в состояние S_k+1 происходит с интенсивностью λ. Интенсивность потока обслуживаний равна μ, это интенсивность освобождения одного работающего в системе канала,
# следовательно, переход из любого состояния S_k в состояние S_k−1 происходит с интенсивностью μ.
#
# Основные формулы для решения задач:
#
# ![](pictures\smo_one_queue_theory.png)

# %% [markdown]
# **Задание 6:**
#
# ![](pictures\smo_one_queue_1.png)

# %%
n = 1 # Количество каналов обслуживания
m = 3 # Длина очереди

λ = 0.4
μ = 0.5
p = λ / μ

print(f'Интенсивность потока судов {λ = } (сут^(-1))')
print(f'Время рагрузки одного судна {μ = } (сут^(-1))')
print(f'Коэффициент загруженности СМО {p = }')
# Out:
# Интенсивность потока судов λ = 0.4 (сут^(-1))
# Время рагрузки одного судна μ = 0.5 (сут^(-1))
# Коэффициент загруженности СМО p = 0.8

# %%
def calculate_p_0(p: float, m: int) -> float:
    """
    Рачсет нахождения системы в состоянии S_0

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанная вероятность
    """
    p_0 = round((1 - p) / (1 - pow(p, m + 2)), 3)
    return p_0

def calculate_p_denial(p: float, m: int) -> float:
    """
    Рачсет вероятности отказа обслуживания

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанная вероятность
    """
    p_0 = calculate_p_0(p, m)
    p_denial = round(pow(p , m + 1) * p_0, 3)
    return p_denial

def calculate_p_queue(p: float, m: int) -> float:
    """
    Рачсет вероятности наличия очереди

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанная вероятность
    """
    p_0 = calculate_p_0(p, m)
    p_queue = round(pow(p, 2) * (1 - pow(p, m)) * p_0 / (1 - p), 3)

    return p_queue

def calculate_Q(p: float, m: int) -> float:
    """
    Расчет вероятности  обслуживания заявки

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанная вероятность
    """
    p_denial = calculate_p_denial(p, m)
    Q = round(1 - p_denial, 3)
    return Q

def calculate_A(p: float, m: int, λ: float) -> float:
    """
    Расчет абсолютной пропускной способности системы

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди
        λ (float): Интенсивность потока судов

    Returns:
        Рассчитанное значение
    """
    Q = calculate_Q(p, m)
    A = round(Q * λ, 3)
    return A

def calculate_L_service(p: float, m: int) -> float:
    """
    Расчет среднего числа заявок, находящихся под обслуживанием
    (вне очереди)

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанное значение
    """
    p_0 = calculate_p_0(p, m)
    L_service = round(1 - p_0, 3)
    return L_service

def calculate_L_queue(p: float, m: int) -> float:
    """
    Расчет среднего числа заявок, находящихся в очереди

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанное значение
    """
    L_queue = pow(p, 2) * (1 - pow(p, m) * (m + 1 - m * p)) / ((1 - pow(p, m + 2)) * (1 - p))
    L_queue = round(L_queue, 3)
    return L_queue

def calculate_L_system(p: float, m: int) -> float:
    """
    Расчет среднего числа заявок в системе

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанное значение
    """
    L_queue = calculate_L_queue(p, m)
    L_service = calculate_L_service(p, m)
    L_system = round(L_queue + L_service, 3)
    return L_system

def calculate_T_service(p: float, m: int, λ: float) -> float:
    """
    Расчет среднего времени нахождения заявки под обслуживанием

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди
        λ (float): Интенсивность потока судов

    Returns:
        Рассчитанное значение
    """
    L_service =  calculate_L_service(p, m)
    T_service = round(L_service / λ, 3)
    return T_service

def calculate_T_queue(p: float, m: int, λ: float) -> float:
    """
    Расчет среднего времени нахождения заявки в очереди

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди
        λ (float): Интенсивность потока судов

    Returns:
        Рассчитанное значение
    """
    L_queue =  calculate_L_queue(p, m)
    T_queue = round(L_queue / λ, 3)
    return T_queue

def calculate_T_system(p: float, m: int, λ: float) -> float:
    """
    Расчет среднего времени нахождения заявки в системе

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди
        λ (float): Интенсивность потока судов

    Returns:
        Рассчитанное значение
    """
    L_system =  calculate_L_system(p, m)
    T_system = round(L_system  / λ , 3)
    return T_system

print(f'Вероятность отказа в обслуживании: {calculate_p_denial(p, m)}')
print(f'Вероятность наличия очереди: {calculate_p_queue(p, m)}')
print(f'Вероятность обслуживания: {calculate_Q(p, m)}')
print(f'Абсолютная пропускная способность системы {calculate_A(p, m, λ)} (сут^(-1))')
print(f'Число заявок под обслуживанием: {calculate_L_service(p, m)}')
print(f'Число заявок в очереди: {calculate_L_queue(p, m)}')
print(f'Число заявок в системе: {calculate_L_system(p, m)}')
print(f'Среднее время заявки под обслуживанием: {calculate_T_service(p, m, λ)} (сут)')
print(f'Среднее время заявки в очереди: {calculate_T_queue(p, m, λ)} (сут)')
print(f'Среднее время заявки в системе:  {calculate_T_system(p, m, λ)} (сут)')
# Out:
# Вероятность отказа в обслуживании: 0.037
# Вероятность наличия очереди: 0.514
# Вероятность обслуживания: 0.963
# Абсолютная пропускная способность системы 1.444 (сут^(-1))
# Число заявок под обслуживанием: 0.722
# Число заявок в очереди: 1.388
# Число заявок в системе: 2.11
# Среднее время заявки под обслуживанием: 0.481 (сут)
# Среднее время заявки в очереди: 0.925 (сут)
# Среднее время заявки в системе:  1.407 (сут)

# %% [markdown]
# **Задание для самостоятельного решения:**
#
# ![image.png](attachment:image.png)

# %%
n = 1 # Количество каналов обслуживания
m = 6 # Длина очереди

λ = 1.5
μ = 2
p = λ / μ

print(f'Интенсивность потока судов {λ = } (сут^(-1))')
print(f'Время рагрузки одного судна {μ = } (сут^(-1))')
print(f'Коэффициент загруженности СМО {p = }')
# Out:
# Интенсивность потока судов λ = 1.5 (сут^(-1))
# Время рагрузки одного судна μ = 2 (сут^(-1))
# Коэффициент загруженности СМО p = 0.75

# %%
def calculate_p_0(p: float, m: int) -> float:
    """
    Рачсет нахождения системы в состоянии S_0

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанная вероятность
    """
    p_0 = round((1 - p) / (1 - pow(p, m + 2)), 3)
    return p_0

def calculate_p_denial(p: float, m: int) -> float:
    """
    Рачсет вероятности отказа обслуживания

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанная вероятность
    """
    p_0 = calculate_p_0(p, m)
    p_denial = round(pow(p , m + 1) * p_0, 3)
    return p_denial

def calculate_p_queue(p: float, m: int) -> float:
    """
    Рачсет вероятности наличия очереди

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанная вероятность
    """
    p_0 = calculate_p_0(p, m)
    p_queue = round(pow(p, 2) * (1 - pow(p, m)) * p_0 / (1 - p), 3)

    return p_queue

def calculate_Q(p: float, m: int) -> float:
    """
    Расчет вероятности  обслуживания заявки

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанная вероятность
    """
    p_denial = calculate_p_denial(p, m)
    Q = round(1 - p_denial, 3)
    return Q

def calculate_A(p: float, m: int, λ: float) -> float:
    """
    Расчет абсолютной пропускной способности системы

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди
        λ (float): Интенсивность потока судов

    Returns:
        Рассчитанное значение
    """
    Q = calculate_Q(p, m)
    A = round(Q * λ, 3)
    return A

def calculate_L_service(p: float, m: int) -> float:
    """
    Расчет среднего числа заявок, находящихся под обслуживанием
    (вне очереди)

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанное значение
    """
    p_0 = calculate_p_0(p, m)
    L_service = round(1 - p_0, 3)
    return L_service

def calculate_L_queue(p: float, m: int) -> float:
    """
    Расчет среднего числа заявок, находящихся в очереди

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанное значение
    """
    L_queue = pow(p, 2) * (1 - pow(p, m) * (m + 1 - m * p)) / ((1 - pow(p, m + 2)) * (1 - p))
    L_queue = round(L_queue, 3)
    return L_queue

def calculate_L_system(p: float, m: int) -> float:
    """
    Расчет среднего числа заявок в системе

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанное значение
    """
    L_queue = calculate_L_queue(p, m)
    L_service = calculate_L_service(p, m)
    L_system = round(L_queue + L_service, 3)
    return L_system

def calculate_T_service(p: float, m: int, λ: float) -> float:
    """
    Расчет среднего времени нахождения заявки под обслуживанием

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди
        λ (float): Интенсивность потока судов

    Returns:
        Рассчитанное значение
    """
    L_service =  calculate_L_service(p, m)
    T_service = round(L_service / λ, 3)
    return T_service

def calculate_T_queue(p: float, m: int, λ: float) -> float:
    """
    Расчет среднего времени нахождения заявки в очереди

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди
        λ (float): Интенсивность потока судов

    Returns:
        Рассчитанное значение
    """
    L_queue =  calculate_L_queue(p, m)
    T_queue = round(L_queue / λ, 3)
    return T_queue

def calculate_T_system(p: float, m: int, λ: float) -> float:
    """
    Расчет среднего времени нахождения заявки в системе

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди
        λ (float): Интенсивность потока судов

    Returns:
        Рассчитанное значение
    """
    L_system =  calculate_L_system(p, m)
    T_system = round(L_system  / λ , 3)
    return T_system

print(f'Вероятность отказа в обслуживании: {calculate_p_denial(p, m)}')
print(f'Вероятность наличия очереди: {calculate_p_queue(p, m)}')
print(f'Вероятность обслуживания: {calculate_Q(p, m)}')
print(f'Абсолютная пропускная способность системы {calculate_A(p, m, λ)} (сут^(-1)')
print(f'Число заявок под обслуживанием: {calculate_L_service(p, m)}')
print(f'Число заявок в очереди: {calculate_L_queue(p, m)}')
print(f'Число заявок в системе: {calculate_L_system(p, m)}')
print(f'Среднее время заявки под обслуживанием: {calculate_T_service(p, m, λ)} (ч)')
print(f'Среднее время заявки в очереди: {calculate_T_queue(p, m, λ)} (ч)')
print(f'Среднее время заявки в системе:  {calculate_T_system(p, m, λ)} (ч)')
# Out:
# Вероятность отказа в обслуживании: 0.037
# Вероятность наличия очереди: 0.514
# Вероятность обслуживания: 0.963
# Абсолютная пропускная способность системы 1.444 (сут^(-1)
# Число заявок под обслуживанием: 0.722
# Число заявок в очереди: 1.388
# Число заявок в системе: 2.11
# Среднее время заявки под обслуживанием: 0.481 (ч)
# Среднее время заявки в очереди: 0.925 (ч)
# Среднее время заявки в системе:  1.407 (ч)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = 1 # Количество каналов обслуживания
m = 6 # Длина очереди

λ = round(1 / 6, 3)
μ = round(1 / 5, 3)
p = round(λ / μ, 3)

print(f'Интенсивность потока судов {λ = } (мин^(-1))')
print(f'Время рагрузки одного судна {μ = } (мин^(-1))')
print(f'Коэффициент загруженности СМО {p = }')
# Out:
# Интенсивность потока судов λ = 0.167 (мин^(-1))
# Время рагрузки одного судна μ = 0.2 (мин^(-1))
# Коэффициент загруженности СМО p = 0.835

# %%
def calculate_p_0(p: float, m: int) -> float:
    """
    Рачсет нахождения системы в состоянии S_0

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанная вероятность
    """
    p_0 = round((1 - p) / (1 - pow(p, m + 2)), 3)
    return p_0

def calculate_p_denial(p: float, m: int) -> float:
    """
    Рачсет вероятности отказа обслуживания

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанная вероятность
    """
    p_0 = calculate_p_0(p, m)
    p_denial = round(pow(p , m + 1) * p_0, 3)
    return p_denial

def calculate_p_queue(p: float, m: int) -> float:
    """
    Рачсет вероятности наличия очереди

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанная вероятность
    """
    p_0 = calculate_p_0(p, m)
    p_queue = round(pow(p, 2) * (1 - pow(p, m)) * p_0 / (1 - p), 3)

    return p_queue

def calculate_Q(p: float, m: int) -> float:
    """
    Расчет вероятности  обслуживания заявки

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанная вероятность
    """
    p_denial = calculate_p_denial(p, m)
    Q = round(1 - p_denial, 3)
    return Q

def calculate_A(p: float, m: int, λ: float) -> float:
    """
    Расчет абсолютной пропускной способности системы

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди
        λ (float): Интенсивность потока судов

    Returns:
        Рассчитанное значение
    """
    Q = calculate_Q(p, m)
    A = round(Q * λ, 3)
    return A

def calculate_L_service(p: float, m: int) -> float:
    """
    Расчет среднего числа заявок, находящихся под обслуживанием
    (вне очереди)

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанное значение
    """
    p_0 = calculate_p_0(p, m)
    L_service = round(1 - p_0, 3)
    return L_service

def calculate_L_queue(p: float, m: int) -> float:
    """
    Расчет среднего числа заявок, находящихся в очереди

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанное значение
    """
    L_queue = pow(p, 2) * (1 - pow(p, m) * (m + 1 - m * p)) / ((1 - pow(p, m + 2)) * (1 - p))
    L_queue = round(L_queue, 3)
    return L_queue

def calculate_L_system(p: float, m: int) -> float:
    """
    Расчет среднего числа заявок в системе

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди

    Returns:
        Рассчитанное значение
    """
    L_queue = calculate_L_queue(p, m)
    L_service = calculate_L_service(p, m)
    L_system = round(L_queue + L_service, 3)
    return L_system

def calculate_T_service(p: float, m: int, λ: float) -> float:
    """
    Расчет среднего времени нахождения заявки под обслуживанием

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди
        λ (float): Интенсивность потока судов

    Returns:
        Рассчитанное значение
    """
    L_service =  calculate_L_service(p, m)
    T_service = round(L_service / λ, 3)
    return T_service

def calculate_T_queue(p: float, m: int, λ: float) -> float:
    """
    Расчет среднего времени нахождения заявки в очереди

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди
        λ (float): Интенсивность потока судов

    Returns:
        Рассчитанное значение
    """
    L_queue =  calculate_L_queue(p, m)
    T_queue = round(L_queue / λ, 3)
    return T_queue

def calculate_T_system(p: float, m: int, λ: float) -> float:
    """
    Расчет среднего времени нахождения заявки в системе

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди
        λ (float): Интенсивность потока судов

    Returns:
        Рассчитанное значение
    """
    L_system =  calculate_L_system(p, m)
    T_system = round(L_system  / λ , 3)
    return T_system

print(f'Вероятность отказа в обслуживании: {calculate_p_denial(p, m)}')
print(f'Вероятность наличия очереди: {calculate_p_queue(p, m)}')
print(f'Вероятность обслуживания: {calculate_Q(p, m)}')
print(f'Абсолютная пропускная способность системы {calculate_A(p, m, λ)} (мин^(-1)')
print(f'Число заявок под обслуживанием: {calculate_L_service(p, m)}')
print(f'Число заявок в очереди: {calculate_L_queue(p, m)}')
print(f'Число заявок в системе: {calculate_L_system(p, m)}')
print(f'Среднее время заявки под обслуживанием: {calculate_T_service(p, m, λ)} (мин)')
print(f'Среднее время заявки в очереди: {calculate_T_queue(p, m, λ)} (мин)')
print(f'Среднее время заявки в системе:  {calculate_T_system(p, m, λ)} (мин)')
# Out:
# Вероятность отказа в обслуживании: 0.061
# Вероятность наличия очереди: 0.603
# Вероятность обслуживания: 0.939
# Абсолютная пропускная способность системы 0.157 (мин^(-1)
# Число заявок под обслуживанием: 0.784
# Число заявок в очереди: 1.801
# Число заявок в системе: 2.585
# Среднее время заявки под обслуживанием: 4.695 (мин)
# Среднее время заявки в очереди: 10.784 (мин)
# Среднее время заявки в системе:  15.479 (мин)

# %% [markdown]
# # Многоканальная СМО с ограниченной очередью
#
# Рассмотрим систему, которая имеет n каналов обслуживания и может обладать очередью, не превышающей m заявок (m > 0).
# Состояния системы будем нумеровать по числу заявок, находящихся в системе, т.е.
# - S_k — состояние системы, когда в ней находится k заявок;
# - S_0 — система свободна: заявок в системе нет;
# - S_1 — занят один канал, обслуживается одна заявка, очереди нет;
# - S_2 — два канала заняты, обслуживаются две заявки, очереди нет; …;
# - S_n — заняты все n каналов, очереди нет;
# - S_n+1 — все n каналов заняты, в очереди стоит одна заявка;
# - S_n+m — все каналы заняты, m заявок стоят в очереди, т. е. все допустимые места в очереди заняты, очередной поступившей в систему заявке будет отказано в обслуживании.
#
# Потоки заявок и обслуживания предполагаются простейшие. Интенсивность входящего потока заявок равна λ, интенсивность потока обслуживаний равна μ.
#
# Размеченный граф системы выглядит следующим образом:
#
# ![image.png](attachment:image.png)
#
# Поток заявок в систему при любом ее состоянии сохраняет свою интенсивность λ, следовательно, для любого состояния системы при приходе очередной заявки переход из состояния S_k в состояние S_k+1 происходит с интенсивностью λ. Интенсивность потока обслуживаний равна μ — интенсивности освобождения одного канала. Следовательно, если заняты k каналов, интенсивность освобождения одного (любого) из них происходит с интенсивностью kμ, переход из состояния S_k в состояние S_k−1 происходит с интенсивностью kμ. Если заняты все n каналов, то интенсивность освобождения одного из них равна nμ. Это максимально возможная интенсивность освобождения каналов, она не зависит от числа заявок, находящихся в очереди. Поэтому переход из состояния S_n+k в состояние S_n+k-1 происходит с постоянной интенсивностью, равной nμ, независимо от числа k заявок, ожидающих обслуживания в очереди.(1≤ ≤ k m).
#
# Основные формулы для решения задач:
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# **Задание 7:**
#
# ![image-8.png](attachment:image-8.png)

# %%
n = 2 # Количество каналов обслуживания
m = 3 # Длина очереди

λ = 1.5
μ = 2
p = λ / μ

print(f'Интенсивность потока машин {λ = } (ч^(-1))')
print(f'Время осмотра одной машины {μ = } (ч^(-1))')
print(f'Коэффициент загруженности СМО {p = }')
# Out:
# Интенсивность потока машин λ = 1.5 (ч^(-1))
# Время осмотра одной машины μ = 2 (ч^(-1))
# Коэффициент загруженности СМО p = 0.75

# %%
from math import factorial


def calculate_p_0(p: float, n: int, m: int) -> float:
    """
    Рачсет нахождения системы в состоянии S_0

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов обслуживания
        m (int): Длина очереди

    Returns:
        Рассчитанная вероятность
    """
    p_0 = 0

    for i in range(0, n + m + 1):
        if i <= n:
            temp = pow(p , i) / factorial(i)
        else:
            temp = pow(p, i) / (factorial(n) * pow(n, i - n))

        p_0 += temp

    p_0 = round(pow(p_0, -1), 3)

    return p_0

def calculate_p_denial(p: float, n: int, m: int) -> float:
    """
    Рачсет вероятности отказа обслуживания

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов обслуживания
        m (int): Длина очереди

    Returns:
        Рассчитанная вероятность
    """
    p_0 = calculate_p_0(p, n, m)
    p_denial = round(pow(p, n + m) * p_0 / (pow(n, m) * factorial(n)), 5)
    return p_denial

def calculate_p_queue(p: float, n: int,  m: int) -> float:
    """
    Рачсет вероятности наличия очереди

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов обслуживания
        m (int): Длина очереди

    Returns:
        Рассчитанная вероятность
    """
    p_0 = calculate_p_0(p, n, m)
    p_queue = round(pow(p, n + 1) * (pow(n, m) - pow(p, m)) / (factorial(n) * pow(n, m) * (n - p)) * p_0, 4)

    return p_queue

def calculate_Q(p: float, n: int, m: int) -> float:
    """
    Расчет вероятности  обслуживания заявки

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов обслуживания
        m (int): Длина очереди

    Returns:
        Рассчитанная вероятность
    """
    p_denial = calculate_p_denial(p, n, m)
    Q = round(1 - p_denial, 4)
    return Q

def calculate_A(p: float, n: int, m: int, λ: float) -> float:
    """
    Расчет абсолютной пропускной способности системы

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов обслуживания
        m (int): Длина очереди
        λ (float): Интенсивность потока судов

    Returns:
        Рассчитанное значение
    """
    Q = calculate_Q(p, n, m)
    A = round(Q * λ, 3)
    return A

def calculate_L_service(p: float, n: int, m: int) -> float:
    """
    Расчет среднего числа заявок, находящихся под обслуживанием
    (вне очереди)

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов облуживания
        m (int): Длина очереди

    Returns:
        Рассчитанное значение
    """
    Q = calculate_Q(p, n, m)
    L_service = p * Q
    return L_service

def calculate_L_queue(p: float, n: int, m: int) -> float:
    """
    Расчет среднего числа заявок, находящихся в очереди

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов обслуживания
        m (int): Длина очереди

    Returns:
        Рассчитанное значение
    """
    p_0 = calculate_p_0(p, n, m)
    L_queue = pow(p, n + 1) * (1 - pow(p / n, m) * (m + 1 - m * (p / n))) * p_0 / (factorial(n) * n * pow(1 - p / n, 2))
    L_queue = round(L_queue, 4)
    return L_queue

def calculate_L_system(p: float, n: int, m: int) -> float:
    """
    Расчет среднего числа заявок в системе

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов обслуживания
        m (int): Длина очереди

    Returns:
        Рассчитанное значение
    """
    L_queue = calculate_L_queue(p, n, m)
    L_service = calculate_L_service(p, n, m)
    L_system = round(L_queue + L_service, 4)
    return L_system

def calculate_T_service(p: float, n: int, m: int, λ: float) -> float:
    """
    Расчет среднего времени нахождения заявки под обслуживанием

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди
        n (int): Количество каналов обслуживания
        λ (float): Интенсивность потока судов

    Returns:
        Рассчитанное значение
    """
    L_service =  calculate_L_service(p, n, m)
    T_service = round(L_service / λ, 4)
    return T_service

def calculate_T_queue(p: float, n: int, m: int, λ: float) -> float:
    """
    Расчет среднего времени нахождения заявки в очереди

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди
        n (int): Количество каналов обслуживания
        λ (float): Интенсивность потока судов

    Returns:
        Рассчитанное значение
    """
    L_queue =  calculate_L_queue(p, n, m)
    T_queue = round(L_queue / λ, 4)
    return T_queue

def calculate_T_system(p: float, n: int, m: int, λ: float) -> float:
    """
    Расчет среднего времени нахождения заявки в системе

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди
        n (int): Количество каналов обслуживания
        λ (float): Интенсивность потока судов

    Returns:
        Рассчитанное значение
    """
    L_system =  calculate_L_system(p, n, m)
    T_system = round(L_system  / λ , 4)
    return T_system

print(f'Вероятность отказа в обслуживании: {calculate_p_denial(p, n, m)}')
print(f'Вероятность наличия очереди: {calculate_p_queue(p, n, m)}')
print(f'Вероятность обслуживания: {calculate_Q(p, n, m)}')
print(f'Абсолютная пропускная способность системы {calculate_A(p, n, m, λ)} (ч^(-1))')
print(f'Число заявок под обслуживанием: {calculate_L_service(p, n, m, )}')
print(f'Число заявок в очереди: {calculate_L_queue(p, n, m)}')
print(f'Число заявок в системе: {calculate_L_system(p, n, m)}')
print(f'Среднее время заявки под обслуживанием: {calculate_T_service(p, n, m, λ)} (ч)')
print(f'Среднее время заявки в очереди: {calculate_T_queue(p, n, m, λ)} (ч)')
print(f'Среднее время заявки в системе:  {calculate_T_system(p, n, m, λ)} (ч)')
# Out:
# Вероятность отказа в обслуживании: 0.00676
# Вероятность наличия очереди: 0.0729
# Вероятность обслуживания: 0.9932
# Абсолютная пропускная способность системы 1.49 (ч^(-1))
# Число заявок под обслуживанием: 0.7449
# Число заявок в очереди: 0.1045
# Число заявок в системе: 0.8494
# Среднее время заявки под обслуживанием: 0.4966 (ч)
# Среднее время заявки в очереди: 0.0697 (ч)
# Среднее время заявки в системе:  0.5663 (ч)

# %% [markdown]
# **Задание для самостоятельного решения:**
#
# ![image.png](attachment:image.png)

# %%
n = 3 # Количество каналов обслуживания
m = 6 # Длина очереди

λ = round(1 / 6, 3)
μ = round(1 / 5, 3)
p = λ / μ

print(f'Интенсивность потока звонков {λ = } (мин^(-1))')
print(f'Время разговора {μ = } (мин^(-1))')
print(f'Коэффициент загруженности СМО {p = }')
# Out:
# Интенсивность потока звонков λ = 0.167 (мин^(-1))
# Время разговора μ = 0.2 (мин^(-1))
# Коэффициент загруженности СМО p = 0.835

# %%
from math import factorial


def calculate_p_0(p: float, n: int, m: int) -> float:
    """
    Рачсет нахождения системы в состоянии S_0

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов обслуживания
        m (int): Длина очереди

    Returns:
        Рассчитанная вероятность
    """
    p_0 = 0

    for i in range(0, n + m + 1):
        if i <= n:
            temp = pow(p , i) / factorial(i)
        else:
            temp = pow(p, i) / (factorial(n) * pow(n, i - n))

        p_0 += temp

    p_0 = round(pow(p_0, -1), 3)

    return p_0

def calculate_p_denial(p: float, n: int, m: int) -> float:
    """
    Рачсет вероятности отказа обслуживания

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов обслуживания
        m (int): Длина очереди

    Returns:
        Рассчитанная вероятность
    """
    p_0 = calculate_p_0(p, n, m)
    p_denial = round(pow(p, n + m) * p_0 / (pow(n, m) * factorial(n)), 5)
    return p_denial

def calculate_p_queue(p: float, n: int,  m: int) -> float:
    """
    Рачсет вероятности наличия очереди

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов обслуживания
        m (int): Длина очереди

    Returns:
        Рассчитанная вероятность
    """
    p_0 = calculate_p_0(p, n, m)
    p_queue = round(pow(p, n + 1) * (pow(n, m) - pow(p, m)) / (factorial(n) * pow(n, m) * (n - p)) * p_0, 4)

    return p_queue

def calculate_Q(p: float, n: int, m: int) -> float:
    """
    Расчет вероятности  обслуживания заявки

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов обслуживания
        m (int): Длина очереди

    Returns:
        Рассчитанная вероятность
    """
    p_denial = calculate_p_denial(p, n, m)
    Q = round(1 - p_denial, 4)
    return Q

def calculate_A(p: float, n: int, m: int, λ: float) -> float:
    """
    Расчет абсолютной пропускной способности системы

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов обслуживания
        m (int): Длина очереди
        λ (float): Интенсивность потока судов

    Returns:
        Рассчитанное значение
    """
    Q = calculate_Q(p, n, m)
    A = round(Q * λ, 3)
    return A

def calculate_L_service(p: float, n: int, m: int) -> float:
    """
    Расчет среднего числа заявок, находящихся под обслуживанием
    (вне очереди)

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов облуживания
        m (int): Длина очереди

    Returns:
        Рассчитанное значение
    """
    Q = calculate_Q(p, n, m)
    L_service = p * Q
    return L_service

def calculate_L_queue(p: float, n: int, m: int) -> float:
    """
    Расчет среднего числа заявок, находящихся в очереди

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов обслуживания
        m (int): Длина очереди

    Returns:
        Рассчитанное значение
    """
    p_0 = calculate_p_0(p, n, m)
    L_queue = pow(p, n + 1) * (1 - pow(p / n, m) * (m + 1 - m * (p / n))) * p_0 / (factorial(n) * n * pow(1 - p / n, 2))
    L_queue = round(L_queue, 4)
    return L_queue

def calculate_L_system(p: float, n: int, m: int) -> float:
    """
    Расчет среднего числа заявок в системе

    Args:
        p (float): Коэффициент загруженности СМО
        n (int): Количество каналов обслуживания
        m (int): Длина очереди

    Returns:
        Рассчитанное значение
    """
    L_queue = calculate_L_queue(p, n, m)
    L_service = calculate_L_service(p, n, m)
    L_system = round(L_queue + L_service, 4)
    return L_system

def calculate_T_service(p: float, n: int, m: int, λ: float) -> float:
    """
    Расчет среднего времени нахождения заявки под обслуживанием

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди
        n (int): Количество каналов обслуживания
        λ (float): Интенсивность потока судов

    Returns:
        Рассчитанное значение
    """
    L_service =  calculate_L_service(p, n, m)
    T_service = round(L_service / λ, 4)
    return T_service

def calculate_T_queue(p: float, n: int, m: int, λ: float) -> float:
    """
    Расчет среднего времени нахождения заявки в очереди

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди
        n (int): Количество каналов обслуживания
        λ (float): Интенсивность потока судов

    Returns:
        Рассчитанное значение
    """
    L_queue =  calculate_L_queue(p, n, m)
    T_queue = round(L_queue / λ, 4)
    return T_queue

def calculate_T_system(p: float, n: int, m: int, λ: float) -> float:
    """
    Расчет среднего времени нахождения заявки в системе

    Args:
        p (float): Коэффициент загруженности СМО
        m (int): Длина очереди
        n (int): Количество каналов обслуживания
        λ (float): Интенсивность потока судов

    Returns:
        Рассчитанное значение
    """
    L_system =  calculate_L_system(p, n, m)
    T_system = round(L_system  / λ , 4)
    return T_system

print(f'Вероятность отказа в обслуживании: {calculate_p_denial(p, n, m)}')
print(f'Вероятность наличия очереди: {calculate_p_queue(p, n, m)}')
print(f'Вероятность обслуживания: {calculate_Q(p, n, m)}')
print(f'Абсолютная пропускная способность системы {calculate_A(p, n, m, λ)} (мин^(-1))')
print(f'Число заявок под обслуживанием: {calculate_L_service(p, n, m, )}')
print(f'Число заявок в очереди: {calculate_L_queue(p, n, m)}')
print(f'Число заявок в системе: {calculate_L_system(p, n, m)}')
print(f'Среднее время заявки под обслуживанием: {calculate_T_service(p, n, m, λ)} (мин)')
print(f'Среднее время заявки в очереди: {calculate_T_queue(p, n, m, λ)} (мин)')
print(f'Среднее время заявки в системе:  {calculate_T_system(p, n, m, λ)} (мин)')
# Out:
# Вероятность отказа в обслуживании: 2e-05
# Вероятность наличия очереди: 0.0161
# Вероятность обслуживания: 1.0
# Абсолютная пропускная способность системы 0.167 (мин^(-1))
# Число заявок под обслуживанием: 0.835
# Число заявок в очереди: 0.0223
# Число заявок в системе: 0.8573
# Среднее время заявки под обслуживанием: 5.0 (мин)
# Среднее время заявки в очереди: 0.1335 (мин)
# Среднее время заявки в системе:  5.1335 (мин)
